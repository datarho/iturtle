# %%
import time

from iturtle import ACTIVE_TURTLES, Screen, Turtle, done

screen = Screen()

leo = Turtle(screen)
donnie = Turtle(screen)

leo.forward(100)
donnie.forward(-100)

# %%
import threading

i = 0
for t in threading.enumerate():
    i += 1
    print(t.name, t.ident, t.is_alive())
print(f'{i} threads')

# %%
done() # In dataphi, it will be called automatically in cell monitor.

# %%
donnie = None # dtor should be activated

# %%
leo.left(120)
leo.forward(100)

# %%
# Threads number must 1 less than previous
i = 0

for t in threading.enumerate():
    i += 1
    print(t.name, t.ident, t.is_alive())
print(f'{i} threads')
